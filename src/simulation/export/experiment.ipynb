# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics


mu = 60
sd = 30

for i in range(1, 15):
    x = np.arange(mu - 3*i*sd, mu + 4*i*sd, 0.1)
    plt.plot(x, norm.pdf(x, i*mu, i*sd))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
