# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from passenger import *

file = open('out_p200e2f10.bin', 'rb')

passengers = pickle.load(file)
file.close


p_dict = [vars(passenger) for passenger in passengers]


p_dict[0]
# Out:
# {'weight': 33.046980729756186,
#  'route': [0, 9, 0, 5, 4, 0],
#  'floor': 0,
#  'route_index': 5,
#  'state': <States.Idle: 1>,
#  'waitingTime': 96,
#  'rideTime': 153}

# %%
data = pd.DataFrame.from_records(p_dict)
data
# Out:
#          weight                  route  floor  route_index        state  \
# 0     33.046981     [0, 9, 0, 5, 4, 0]      0            5  States.Idle
# 1     78.810268        [0, 4, 3, 6, 0]      0            4  States.Idle
# 2     31.638280  [0, 5, 1, 5, 9, 7, 0]      0            6  States.Idle
# 3     48.047090        [0, 2, 7, 6, 0]      0            4  States.Idle
# 4    107.052435              [0, 7, 0]      0            2  States.Idle
# ..          ...                    ...    ...          ...          ...
# 195   62.369016           [0, 3, 1, 0]      0            3  States.Idle
# 196   70.977687  [0, 8, 7, 4, 8, 5, 0]      0            6  States.Idle
# 197   34.907741     [0, 7, 4, 3, 7, 0]      0            5  States.Idle
# 198   38.831600  [0, 9, 4, 1, 8, 3, 0]      0            6  States.Idle
# 199   73.229123              [0, 5, 0]      0            2  States.Idle
#
#      waitingTime  rideTime
# 0             96       153
# 1             96       175
# 2            194       412
# 3             66        85
# 4             59       130
# ..           ...       ...
# 195           45        68
# 196          139       160
# 197           80       123
# 198          241       186
# 199           36        54
#
# [200 rows x 7 columns]

# %%
data['weight'].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['meanWait'] = data.waitingTime / data['route'].map(len)
data
# Out:
#          weight                  route  floor  route_index        state  \
# 0     33.046981     [0, 9, 0, 5, 4, 0]      0            5  States.Idle
# 1     78.810268        [0, 4, 3, 6, 0]      0            4  States.Idle
# 2     31.638280  [0, 5, 1, 5, 9, 7, 0]      0            6  States.Idle
# 3     48.047090        [0, 2, 7, 6, 0]      0            4  States.Idle
# 4    107.052435              [0, 7, 0]      0            2  States.Idle
# ..          ...                    ...    ...          ...          ...
# 195   62.369016           [0, 3, 1, 0]      0            3  States.Idle
# 196   70.977687  [0, 8, 7, 4, 8, 5, 0]      0            6  States.Idle
# 197   34.907741     [0, 7, 4, 3, 7, 0]      0            5  States.Idle
# 198   38.831600  [0, 9, 4, 1, 8, 3, 0]      0            6  States.Idle
# 199   73.229123              [0, 5, 0]      0            2  States.Idle
#
#      waitingTime  rideTime   meanWait
# 0             96       153  16.000000
# 1             96       175  19.200000
# 2            194       412  27.714286
# 3             66        85  13.200000
# 4             59       130  19.666667
# ..           ...       ...        ...
# 195           45        68  11.250000
# 196          139       160  19.857143
# 197           80       123  13.333333
# 198          241       186  34.428571
# 199           36        54  12.000000
#
# [200 rows x 8 columns]

# %%
data.meanWait.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
